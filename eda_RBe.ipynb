# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ArSAS.txt', sep ="\t")

# %%
df.head(100)
# Out:
#              #Tweet_ID                                         Tweet_text  \
# 0   929241870508724224  المباراة القـادمة #غانا x #مصر الجولة الأخيرة ...
# 1   928942264583376897  هل هذه هي سياسة خارجيه لدوله تحترم نفسها والآخ...
# 2   928615163250520065  وزير خارجية فرنسا عن منتدى شباب العالم: شعرت ب...
# 3   931614713368186880  ومع السيسي و بشار و ايران و بن زايد و والا خلي...
# 4   929755693011427331  أهداف مباراة غانا 0 مصر 1 تصفيات كأس العالم 20...
# 5   930547691393896448  طبعا 25 يناير ثورة محترمة ونفخر بها كان فيها ع...
# 6   928645180873469953  #WeNeedToTalk #منتدي #شباب #العالم #شرم_الشيخ ...
# 7   932183451175997440  يعنى رايح تعتقل ماهيتور المصرى تانى بحجة اشترا...
# 8   932176345400008705  #قولوا_ل_قطر كبتن نامق أن الحل ب #الرياض وان م...
# 9   929607749461250048  بسم الله نبدأ 👏 نغرد علي وسم 👇 👇 👇 👇 👇 ↩ #شباب...
# 10  927848950991937536  هذا الربيع العربي صحيح وسليم اجتثاث روس الفساد...
# 11  927626799764434945  ✨ ملابس السيدة الأولى بحفل الافتتاح رسالة دعم ...
# ...

# %%
df.shape
# Out:
# (19897, 7)

# %%
df2 = pd.read_csv('ArSAS.txt', encoding='utf8', engine='python')

# %%
df2.shape
# Out:
# (21064, 1)

# %%
df2.head(20)
# Out:
#    #Tweet_ID\tTweet_text\tTopic\tSentiment_label\tSentiment_label_confidence\tSpeech_act_label\tSpeech_act_label_confidence
# 0   929241870508724224\tالمباراة القـادمة #غانا x ...
# 1   928942264583376897\tهل هذه هي سياسة خارجيه لدو...
# 2   928615163250520065\tوزير خارجية فرنسا عن منتدى...
# 3   931614713368186880\tومع السيسي و بشار و ايران ...
# 4   929755693011427331\tأهداف مباراة غانا 0 مصر 1 ...
# 5   930547691393896448\tطبعا 25 يناير ثورة محترمة ...
# 6   928645180873469953\t#WeNeedToTalk #منتدي #شباب...
# 7   932183451175997440\tيعنى رايح تعتقل ماهيتور ال...
# 8   932176345400008705\t#قولوا_ل_قطر كبتن نامق أن ...
# 9   929607749461250048\tبسم الله نبدأ 👏 نغرد علي و...
# 10  927848950991937536\tهذا الربيع العربي صحيح وسل...
# 11  927626799764434945\t✨ ملابس السيدة الأولى بحفل...
# 12  927948381120581636\tدول المال أفسدوا ثورات الر...
# 13  928932760017866754\tرحم الله شهداء ثورة يناير ...
# 14  931152577353469056\tتصفيات كاس العالم اوربا اي...
# ...

# %%
df2.iloc[18]
# Out:
# #Tweet_ID\tTweet_text\tTopic\tSentiment_label\tSentiment_label_confidence\tSpeech_act_label\tSpeech_act_label_confidence    929676697372446720\tمدرب غانا يكشف لماذا لا يفرح بغياب محمد صلاح https://t.co/io3eGbgs0b https://t.co/n1fWdK0FZ\tEntity\tNeutral\t1\tAssertion\t1
# Name: 18, dtype: object

# %%
df2.iloc[19]
# Out:
# #Tweet_ID\tTweet_text\tTopic\tSentiment_label\tSentiment_label_confidence\tSpeech_act_label\tSpeech_act_label_confidence    929060064434052992\tبعد قليل مباراة الجزائر - نيجيريا تصفيات كأس العالم | حفيظ دراجي شاهد المباراة : https://t.co/5NMliI9lDs حمل تطبيق... https://t.co/7iLrbQdRLb\tEvent\tNeutral\t1\tAssertion\t1
# Name: 19, dtype: object

# %%
df2.iloc[17]
# Out:
# #Tweet_ID\tTweet_text\tTopic\tSentiment_label\tSentiment_label_confidence\tSpeech_act_label\tSpeech_act_label_confidence    926562086976675840\t" ههههه الخرائط تثبت ان تيران و صنافير سعودية 😂😂بطلوا شغل كيد النساء\tLong_Standing\tNegative\t0.67\tExpression\t1
# Name: 17, dtype: object

# %%
df2.iloc[16]
# Out:
# #Tweet_ID\tTweet_text\tTopic\tSentiment_label\tSentiment_label_confidence\tSpeech_act_label\tSpeech_act_label_confidence    927678782676393984\t#WeNeedToTalkيا شباب العالم روحوا زوروا السجون المصرية وشوفوا عدد الشباب اللى فيها.#منتدى_شباب_العالم\tEvent\tNegative\t1\tExpression\t0.65
# Name: 16, dtype: object

# %%
pd.options.display.max_colwidth = 1000
